# %% [markdown]
# # Lab | List, Dict and Set Comprehension

# %% [markdown]
# ## Exercise: Managing Customer Orders Optimized with Comprehension

# %% [markdown]
# In the previous exercise, you developed a program to manage customer orders and inventory. Now, let's take it a step further and incorporate comprehension into your code.
#
# Follow the steps below to complete the exercise:
#
# 1. Review your code from the previous exercise and identify areas where you can apply comprehension to simplify and streamline your code.
#
#     - *Hint: Apply it to initialize inventory, updating the inventory and printing the updated inventory.*
#
#     - For example, in initializing the inventory, we could have:
#
#         ```python
#         def initialize_inventory(products):
#             inventory = {product: int(input(f"Enter the quantity of {product}s available: ")) for product in products}
#             return inventory
#
#         ```
# <br>
#
#
# 2. Modify the function get_customer_orders so it prompts the user to enter the number of customer orders and gathers the product names using a loop and user input. Use comprehension.
#
# 3. Add a new function to calculate the total price of the customer order. For each product in customer_orders, prompt the user to enter the price of that product. Use comprehension to calculate the total price. Note: assume that the user can only have 1 unit of each product.
#
# 4. Modify the update_inventory function to remove the product from the inventory if its quantity becomes zero after fulfilling the customer orders. Use comprehension to filter out the products with a quantity of zero from the inventory.
#
# 5. Print the total price of the customer order.
#
# Your code should produce output similar to the following:
#
# ```python
# Enter the quantity of t-shirts available:  5
# Enter the quantity of mugs available:  4
# Enter the quantity of hats available:  3
# Enter the quantity of books available:  2
# Enter the quantity of keychains available:  1
# Enter the number of customer orders:  2
# Enter the name of a product that a customer wants to order:  hat
# Enter the name of a product that a customer wants to order:  keychain
#
# Order Statistics:
# Total Products Ordered: 2
# Percentage of Unique Products Ordered: 40.0
#
# Updated Inventory:
# t-shirt: 5
# mug: 4
# hat: 2
# book: 2
# Enter the price of keychain:  5
# Enter the price of hat:  10
# Total Price: 15.0
#
# ```

# %%
#ex 1

products = ["t-shirt", "mug", "hat", "book", "keychain"]


# Products
products = ["t-shirt", "mug", "hat", "book", "poster"]


#Update initialize inventory 
def initialize_inventory(products):
    return {
        product: int(input(f"Enter the quantity of {product}: "))
        for product in products
    }


# Get customer orders
def get_customer_orders():
    customer_orders = set()

    product_list = ", ".join(
        f"{index}) {product}"
        for index, product in enumerate(products, start=1)
    )

    while True:
        product = input(
            f"Which product would you like to order from the list?\n"
            f"{product_list}\n"
            f"Enter the number or product name: "
        )

        # If the user enters a number
        if product.isdigit():
            number = int(product)

            if 1 <= number <= len(products):
                product = products[number - 1]
                customer_orders.add(product.lower())
            else:
                print("Please enter a valid product number.")

        # If the user enters a product name
        elif product.lower() in products:
            customer_orders.add(product.lower())

        else:
            print(f"Sorry, '{product}' is not a valid product.")

        # Ask if user wants another product
        another = input(
            "Do you want to add another product? (yes/no) "
        )

        if another.lower() not in ["yes", "y"]:
            break

    return customer_orders


# Update  update inventory
def update_inventory(customer_orders, inventory):
    return {
        product: quantity - 1 if product in customer_orders else quantity
        for product, quantity in inventory.items()
    }


# 4. Calculate order statistics
def calculate_order_statistics(customer_orders, products):
    total_prod_ordered = len(customer_orders)
    total_prod_available = len(products)

    percentage_unique_prod_ordered = (
        total_prod_ordered / total_prod_available
    ) * 100

    return total_prod_ordered, percentage_unique_prod_ordered


# 5. Print order statistics
def print_order_statistics(order_statistics):
    print(
        f"Order Statistics:\n"
        f"Total Products Ordered: {order_statistics[0]}\n"
        f"Percentage of Products Ordered: {order_statistics[1]}%"
    )


# Update print inventory
def print_updated_inventory(inventory):
    print("\nUpdated Inventory:")

    lines = [
        f"{product}: {quantity}"
        for product, quantity in inventory.items()
    ]

    print("\n".join(lines))


# Run run all

inventory = initialize_inventory(products)

customer_orders = get_customer_orders()

inventory = update_inventory(customer_orders, inventory)

order_statistics = calculate_order_statistics(
    customer_orders,
    products
)

print_order_statistics(order_statistics)

print_updated_inventory(inventory)
# Out:
# Order Statistics:
# Total Products Ordered: 4
# Percentage of Products Ordered: 80.0%
#
# Updated Inventory:
# t-shirt: 3
# mug: 4
# hat: 5
# book: 6
# poster: 3

# %%
#ex 2

#Change get custumer order to ask how many items they want at start 
def get_customer_orders():
    customer_orders = set()

    product_list = ", ".join( f"{index}) {product}" for index, product in enumerate(products, start=1) )

    number_of_orders = int( input("How many products would you like to order? ") )

    for _ in range(number_of_orders): 
        product = input( 
            f"Which product would you like to order?\n" 
            f"{product_list}\n" 
            f"Enter the number or product name: " 
            )

        # If the user enters a number
        if product.isdigit():
            number = int(product)
        
            if 1 <= number <= len(products):
                product = products[number - 1]
                customer_orders.add(product.lower())
            else:
                print("Please enter a valid product number.")
        
        # If the user enters a product name
        elif product.lower() in products:
            customer_orders.add(product.lower())
        
        else:
            print(f"Sorry, '{product}' is not a valid product.")
                       
    return customer_orders

# %%
get_customer_orders()
# Out:
# {'book', 'hat', 'mug'}

# %%
#ex 3

def calculate_total_price(customer_orders):
    total_price = sum( float(input(f"Enter the price of {product}: ")) for product in customer_orders ) 

    return total_price

# %%
total_price = calculate_total_price(customer_orders)

print(f"Total Price: €{total_price}")
# Out:
# Total Price: €100.0

# %%
#ex 4

def update_inventory(customer_orders, inventory):
    updated_inventory = { product: quantity - 1 if product in customer_orders else quantity for product, quantity in inventory.items() } 
    inventory = { product: quantity for product, quantity in updated_inventory.items() if quantity > 0 } 

    return inventory

# %%
update_inventory(customer_orders, inventory)
# Out:
# {'t-shirt': 2, 'mug': 3, 'hat': 4, 'book': 5, 'poster': 3}

# %%
#ex 5

for item, value in inventory.items():
    print(f"Enter the quantity of {item}s available: {value}")

print(f"Enter the number of customer orders: {len(customer_orders)}")

for item in customer_orders:
    print(f"Enter the name of a product that a customer wants to order: {item}")

print()

print_order_statistics(order_statistics)

print_updated_inventory(inventory)
# Out:
# Enter the quantity of mugs available: 1
# Enter the quantity of hats available: 2
# Enter the quantity of books available: 3
# Enter the quantity of posters available: 5
# Enter the number of customer orders: 4
# Enter the name of a product that a customer wants to order: t-shirt
# Enter the name of a product that a customer wants to order: mug
# Enter the name of a product that a customer wants to order: hat
# Enter the name of a product that a customer wants to order: book
#
# Order Statistics:
# Total Products Ordered: 4
# Percentage of Products Ordered: 80.0%
#
# Updated Inventory:
# mug: 1
# hat: 2
# book: 3
# poster: 5
